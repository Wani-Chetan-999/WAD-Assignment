# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('air-quality-india.csv')
df = data.iloc[::10]  # Now it's ~2000 rows
df
# Out:
#                  Timestamp  Year  Month  Day  Hour   PM2.5
# 0      2017-11-07 12:00:00  2017     11    7    12   64.51
# 10     2017-11-07 22:00:00  2017     11    7    22   88.10
# 20     2017-11-08 08:00:00  2017     11    8     8  107.47
# 30     2017-11-08 19:00:00  2017     11    8    19  148.35
# 40     2017-11-09 05:00:00  2017     11    9     5  128.94
# ...                    ...   ...    ...  ...   ...     ...
# 36150  2022-06-02 22:00:00  2022      6    2    22   42.61
# 36160  2022-06-03 08:00:00  2022      6    3     8   37.69
# 36170  2022-06-03 18:00:00  2022      6    3    18   43.93
# 36180  2022-06-04 04:00:00  2022      6    4     4   43.65
# 36190  2022-06-04 14:00:00  2022      6    4    14   35.29
#
# [3620 rows x 6 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Timestamp'], df['PM2.5'], color='blue')
plt.title('PM2.5 Levels Over Time')
plt.xlabel('Timestamp')
plt.ylabel('PM2.5')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Month', y='PM2.5', data=df, estimator='mean', palette='viridis')
plt.title('Average PM2.5 by Month')
plt.xlabel('Month')
plt.ylabel('Average PM2.5')
plt.show()
# Out:
# C:\Users\Chetan\AppData\Local\Temp\ipykernel_17452\3634628022.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Month', y='PM2.5', data=df, estimator='mean', palette='viridis')

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df[['PM2.5', 'Year', 'Month', 'Day', 'Hour']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Hour', y='PM2.5', alpha=0.6)
plt.title('PM2.5 vs Hour of the Day')
plt.xlabel('Hour')
plt.ylabel('PM2.5')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['PM2.5'], kde=True, bins=30, color='teal')
plt.title('PM2.5 Distribution')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Hour', y='PM2.5', data=df)
plt.title('Boxplot of PM2.5 by Hour')
plt.xlabel('Hour')
plt.ylabel('PM2.5')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Month', y='PM2.5', data=df, inner='quartile', palette='Set2')
plt.title('Violin Plot of PM2.5 by Month')
plt.xlabel('Month')
plt.ylabel('PM2.5')
plt.show()
# Out:
# C:\Users\Chetan\AppData\Local\Temp\ipykernel_17452\3348527819.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Month', y='PM2.5', data=df, inner='quartile', palette='Set2')

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Timestamp', y='PM2.5', data=df)
plt.title('Time Series of PM2.5')
plt.xlabel('Timestamp')
plt.ylabel('PM2.5')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
