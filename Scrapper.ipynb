# %%
# !pip install requests

# %%
# !pip install bs4

# %%
import requests
import bs4

# %%
sourceCode=requests.get("https://www.flipkart.com/egate-s9-pro-gold-eo9024-14000-lm-2-speaker-wireless-remote-controller-duster-8x-100-dust-proof-800-iso-lumen-1080p-native-4k-hdr-hdmi-arc-18watt-dsp-audio-voice-1gb-32gb-triple-wifi6-netflix-automatic-android-projector/p/itm23eebf0c9b927?pid=PROGK5N6C9FH9FGM&lid=LSTPROGK5N6C9FH9FGM6G48SO&marketplace=FLIPKART&store=6bo%2Ftia%2F1hx&srno=b_1_8&otracker=browse&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_4_L2_view-all&fm=organic&iid=f63bd5c8-a5fb-4bb1-a6a3-6ea7616b6075.PROGK5N6C9FH9FGM.SEARCH&ppt=browse&ppn=browse")
sourceCode
# Out:
# <Response [200]>

# %%
soup=bs4.BeautifulSoup(sourceCode.text)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.title.text)
# Out:
# Egate S9 Pro Gold (EO9024) (14000 lm / 2 Speaker / Wireless / Remote Controller) Duster 8X | 100% Dust Proof | 800 ISO Lumen | 1080p Native & 4K HDR | HDMI ARC | 18watt DSP Audio | Voice Remote | 1GB-32GB | Triple Wifi6 | Netflix | Automatic Android Projector Price in India - Buy Egate S9 Pro Gold (EO9024) (14000 lm / 2 Speaker / Wireless / Remote Controller) Duster 8X | 100% Dust Proof | 800 ISO Lumen | 1080p Native & 4K HDR | HDMI ARC | 18watt DSP Audio | Voice Remote | 1GB-32GB | Triple Wifi6 | Netflix | Automatic Android Projector online at Flipkart.com

# %%
sourceCode.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.8dd48d.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4e719.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Fli
# ...

# %%
ratings=soup.find('div',{'class':'ipqd2A'}).get_text()
print("Ratings "+ratings)
# Out:
# Ratings 3.8

# %%
ratingsAll=soup.findAll('div',{'class':'XQDdHH Ga3i8K'})
user=soup.findAll('p',{'class':'_2NsDsF AwS1CA'})
review=soup.findAll('div',{'class':'ZmyHeo'})

for i in range(len(ratingsAll)):
    
    print("Rating \t\t Name \n ")
    print(ratingsAll[i].get_text(strip=True) + '\t\t' + user[i].get_text(strip=True) +'\n\n'+'Reviews : '+review[i].get_text(strip=True))
    print('\n')
# Out:
# Rating 		 Name
#
# 4		Ravi Ranjan
#
# Reviews : Value for money..Audio nor working with firetv stick...But working great with any other android tv stickCHECKED PERSONALLYbrightness is very goodVisibility good with dim surrounding lightsPicture quality is also awesomeIts internal android is also working great...But its remote dont have mic to search easily...So i am using android tv stickREAD MORE
#
#
# Rating 		 Name
#
# 4		SUBRAMANIYAN  SUDHAKAR
#
# Reviews : Good picture quality (not the best),Good brightnessDigital focus works fine,Build quality goodFan noise not disturbing movie experienceHDR support with High speed  cableTry to Reconnect if not showing HDR OptionDislikes:HDMI verson 1.4 only ( 2+  is better)Definitely overpriced ( Bangdood, Aliexpress selling Same quality projectors for 12 to 16 INR only - but shipment stoped to India )Minimal Edge and corner blur is  presentREAD MORE
#
#
# Rating 		 Name
#
# 5		S bhaskar Saragadam
#
# ...
